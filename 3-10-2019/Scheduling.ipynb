# %%
import pygal

# %%
Cbar = pygal.StackedBar()

# %%
Cbar.title = 'CPU Scheduling'

# %%
Cbar.x_labels = map(str, ('cpu1', 'cpu2','cpu3'))

# %%
from collections import Counter
from itertools import count

jobs = [1.1,2.1,3,1,0.7,5,3,2,0.9,1.8,4.6,3.1,1.6,0.6,2.8]
jobs.sort(reverse=True)
time1=0
time2=0
time3=0
cpu1=[]
cpu2=[]
cpu3=[]
while len(jobs)!=0:
    #print(jobs)
    if time1==min(time1,time2,time3):
        time1+=jobs[0]/2.66
        cpu3.append(jobs[0])
        o=str(jobs[0])
        Cbar.add(o, [0,0,jobs[0]/2.66])
    elif time2==min(time1,time2,time3):
        time2+=jobs[0]/2
        cpu2.append(jobs[0])
        o=str(jobs[0])
        Cbar.add(o, [0,jobs[0]/2,0])
    elif time3==min(time1,time2,time3):
        time3+=jobs[0]/1.33
        cpu1.append(jobs[0])
        o=str(jobs[0])
        Cbar.add(o, [jobs[0]/1.33,0,0])
    jobs.pop(0)
    
print(max(time1,time2,time3))
print("CPU1:", cpu1)
print("CPU2:", cpu2)
print("CPU3:", cpu3)
# Out:
# 5.639097744360901
# CPU1: [3.1, 2.8, 1.6]
# CPU2: [4.6, 3, 1.8, 1, 0.7]
# CPU3: [5, 3, 2.1, 2, 1.1, 0.9, 0.6]

# %%
Cbar
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.7/site-packages/pygal/graph/base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# /usr/local/lib/python3.7/site-packages/pygal/graph/public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
# ...
